# %%
# %matplotlib inline
from IPython.display import clear_output
from matplotlib import pyplot as plt
import random
import numpy as np

M = np.zeros((100, 100, 3))
for i in range(100):
    #clear_output(wait=True)
    for j in range(100):
        x = random.randrange(0, 100)
        y = random.randrange(0, 100)
        r = random.random() * 10.0
        g = random.random() * 10.0
        b = random.random() * 10.0
        M[x, y] = np.array([0.90, 0.9200, 0.9200])
    plt.figure(figsize=(7,5))
    plt.imshow(M)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a9275750e60b> in <module>()
#      16         M[x, y] = np.array([0.90, 0.9200, 0.9200])
#      17     plt.figure(figsize=(7,5))
# ---> 18     plt.imshow(M)
#      19     plt.show()
#      20
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, **kwargs)
#    2879            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    2880            hold=None, **kwargs):
# -> 2881     ax = gca()
#    2882     # allow callers to override the hold state by passing hold=True|False
#    2883     washold = ax.ishold()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.pyc in gca(**kwargs)
#     801     """
#     802
# --> 803     ax =  gcf().gca(**kwargs)
#     804     return ax
#     805
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/figure.pyc in gca(self, **kwargs)
#    1219
#    1220         # no axes found, so create one which spans the figure
# -> 1221         return self.add_subplot(1, 1, 1, **kwargs)
#    1222
#    1223     def sca(self, a):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#     912                     self._axstack.remove(ax)
#     913
# --> 914             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     915
#     916         self._axstack.add(key, a)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in __init__(self, fig, *args, **kwargs)
#    9257
#    9258         # _axes_class is set in the subplot_class_factory
# -> 9259         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#    9260
#    9261     def __reduce__(self):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     459         self._hold = rcParams['axes.hold']
#     460         self._connected = {}  # a dict from events to (id, func)
# --> 461         self.cla()
#     462         # funcs used to format x and y - fall back on major formatters
#     463         self.fmt_xdata = None
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.pyc in cla(self)
#     845         self.yaxis.cla()
#     846         for name, spine in self.spines.iteritems():
# --> 847             spine.cla()
#     848
#     849         self.ignore_existing_data_limits = True
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/spines.pyc in cla(self)
#     157         self._position = None  # clear position
#     158         if self.axis is not None:
# --> 159             self.axis.cla()
#     160
#     161     def is_frame_like(self):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axis.pyc in cla(self)
#     740         self._set_artist_props(self.label)
#     741
# --> 742         self.reset_ticks()
#     743
#     744         self.converter = None
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axis.pyc in reset_ticks(self)
#     754
#     755         self.majorTicks.extend([self._get_tick(major=True)])
# --> 756         self.minorTicks.extend([self._get_tick(major=False)])
#     757         self._lastNumMajorTicks = 1
#     758         self._lastNumMinorTicks = 1
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axis.pyc in _get_tick(self, major)
#    1607         else:
#    1608             tick_kw = self._minor_tick_kw
# -> 1609         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1610
#    1611     def _get_label(self):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     144         self.label1 = self._get_text1()
#     145         self.label = self.label1  # legacy name
# --> 146         self.label2 = self._get_text2()
#     147
#     148         self.gridOn = gridOn
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axis.pyc in _get_text2(self)
#     369             color=self._labelcolor,
#     370             verticalalignment=vert,
# --> 371             horizontalalignment=horiz,
#     372             )
#     373         t.set_transform(trans)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, **kwargs)
#     179         if fontproperties is None:
#     180             fontproperties = FontProperties()
# --> 181         elif is_string_like(fontproperties):
#     182             fontproperties = FontProperties(fontproperties)
#     183
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/cbook.pyc in is_string_like(obj)
#     666
#     667
# --> 668 def is_string_like(obj):
#     669     'Return True if *obj* looks like a string'
#     670     if isinstance(obj, (str, unicode)):
#
# KeyboardInterrupt:
